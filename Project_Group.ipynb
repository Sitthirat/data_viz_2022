# %% [markdown]
# <a href="https://colab.research.google.com/github/Sitthirat/data_viz_2022/blob/main/Project_Group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #เตรียมตาราง

# %% [markdown]
# # ลิ้ง Google Drive
#
# https://drive.google.com/drive/folders/19rdHZd6evdPp7lZhjy_0pI7AEa5BJ2-9?usp=sharing

# %%
import pandas as pd #ส่วนของการ Import
import os

# %%
from google.colab import drive  #เชื่อม google drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/ProjectFinal'   #pathจะชี้ไปยังโฟล์เดอร์
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##ตาราง Covid-19

# %%
data_file_path = os.path.join(path,'confirmed-cases.csv') #แล้วก็ชี้ไปที่ไฟล์ confirmed-cases.csv
covid1 = pd.read_csv(data_file_path)
covid1#แสดงตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 839766             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839767             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839768             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839769             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
# 839770             กาญจนบุรี                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 839766         กาญจนบุรี               NaN
# 839767         กาญจนบุรี               NaN
# 839768         กาญจนบุรี               NaN
# 839769         กาญจนบุรี               NaN
# 839770         กาญจนบุรี               NaN
#
# [839771 rows x 11 columns]

# %%
covid2 = pd.read_csv(os.path.join(path,'confirmed-cases-since-120864.csv')) #เรียกไฟล์ confirmed-cases-since-120864.csv
covid2#แสดงตาราง
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# 0                    เชียงราย                                        อื่นๆ
# 1                    เชียงราย                                        อื่นๆ
# 2                    เชียงราย                                        อื่นๆ
# 3                    เชียงราย                                        อื่นๆ
# 4                    เชียงราย  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                          ...
# 1042163         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042164         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042165         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042166         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 1042167             เชียงใหม่                             ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                     NaN               NaN
# 1                     NaN               NaN
# 2                     NaN               NaN
# 3                     NaN               NaN
# 4                     NaN               NaN
# ...                   ...               ...
# 1042163               NaN               NaN
# 1042164               NaN               NaN
# 1042165               NaN               NaN
# 1042166               NaN               NaN
# 1042167               NaN               NaN
#
# [1042168 rows x 11 columns]

# %%
covid3 = pd.read_csv(os.path.join(path,'confirmed-cases-since-271064.csv')) #เรียกไฟล์ confirmed-cases-since-271064.csv
covid3 = covid3.drop('Unnamed: 11', axis=1) #ลบคอลัมน์ Unnamed: 11
covid3#แสดงตาราง
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# 0                       ลำปาง                                          อื่นๆ
# 1                       ลำปาง                                          อื่นๆ
# 2                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 3                       ลำปาง  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 4                       ลำปาง    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                       ...                                            ...
# 1010454         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010455         กรุงเทพมหานคร                               ทัณฑสถาน/เรือนจำ
# 1010456               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010457               ปัตตานี                               ทัณฑสถาน/เรือนจำ
# 1010458               ปัตตานี                               ทัณฑสถาน/เรือนจำ
#
#         province_of_onset district_of_onset
# 0                   ลำปาง        เมืองลำปาง
# 1                   ลำปาง        เมืองลำปาง
# 2                   ลำปาง          ห้างฉัตร
# 3                   ลำปาง          ห้างฉัตร
# 4                   ลำปาง        เมืองลำปาง
# ...                   ...               ...
# 1010454               NaN               NaN
# 1010455               NaN               NaN
# 1010456               NaN               NaN
# 1010457               NaN               NaN
# 1010458               NaN               NaN
#
# [1010459 rows x 11 columns]

# %%
covid4 = pd.read_csv(os.path.join(path,'confirmed-cases-since-280265.csv')) #เรียกไฟล์ confirmed-cases-since-280265.csv
covid4#แสดงตาราง
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 433548         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                             ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [433553 rows x 11 columns]

# %% [markdown]
# ##รวมตาราง Covid-19

# %%
merge_covid = pd.concat([covid1,covid2,covid3,covid4]) # รวมตารางในแรวตั้งโดยใช้คำสั่ง pd.concat
merge_covid#แสดงตาราง
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 433548         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                  ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0          กรุงเทพมหานคร               NaN
# 1          กรุงเทพมหานคร               NaN
# 2                 นครปฐม             เมือง
# 3          กรุงเทพมหานคร               NaN
# 4          กรุงเทพมหานคร               NaN
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [3325951 rows x 11 columns]

# %% [markdown]
# ###เลือกข้อมูลที่ต้องการ

# %%
data_covid = merge_covid[['No.','announce_date','sex','age','Unit','province_of_onset','risk']] #เลือกคอลัมน์ที่ต้องการ
data_covid #แสดงตาราง
# Out:
#             No. announce_date   sex   age Unit province_of_onset  \
# 0             1     12/1/2020  หญิง  61.0   ปี     กรุงเทพมหานคร
# 1             2     17/1/2020  หญิง  74.0   ปี     กรุงเทพมหานคร
# 2             3     22/1/2020  หญิง  73.0   ปี            นครปฐม
# 3             4     22/1/2020   ชาย  68.0   ปี     กรุงเทพมหานคร
# 4             5     24/1/2020  หญิง  66.0   ปี     กรุงเทพมหานคร
# ...         ...           ...   ...   ...  ...               ...
# 433548  3303165     18/3/2022  หญิง   NaN  NaN               NaN
# 433549  3303166     18/3/2022  หญิง   NaN  NaN               NaN
# 433550  3303167     18/3/2022  หญิง   NaN  NaN               NaN
# 433551  3303168     18/3/2022  หญิง   NaN  NaN               NaN
# 433552  3303169     18/3/2022  หญิง   NaN  NaN               NaN
#
#                                     risk
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                                  ...
# 433548                  ทัณฑสถาน/เรือนจำ
# 433549                  ทัณฑสถาน/เรือนจำ
# 433550                  ทัณฑสถาน/เรือนจำ
# 433551                  ทัณฑสถาน/เรือนจำ
# 433552                  ทัณฑสถาน/เรือนจำ
#
# [3325951 rows x 7 columns]

# %%
clean_covid = data_covid.rename(columns = {'province_of_onset':'จังหวัดที่ติดเชื้อ'}) #ใช้คำสั่ง rename เปลี่ยน province_of_onset เป็น จังหวัดที่ติดเชื่อ
clean_covid #แสดงตาราง
# Out:
#             No. announce_date   sex   age Unit จังหวัดที่ติดเชื้อ  \
# 0             1     12/1/2020  หญิง  61.0   ปี      กรุงเทพมหานคร
# 1             2     17/1/2020  หญิง  74.0   ปี      กรุงเทพมหานคร
# 2             3     22/1/2020  หญิง  73.0   ปี             นครปฐม
# 3             4     22/1/2020   ชาย  68.0   ปี      กรุงเทพมหานคร
# 4             5     24/1/2020  หญิง  66.0   ปี      กรุงเทพมหานคร
# ...         ...           ...   ...   ...  ...                ...
# 433548  3303165     18/3/2022  หญิง   NaN  NaN                NaN
# 433549  3303166     18/3/2022  หญิง   NaN  NaN                NaN
# 433550  3303167     18/3/2022  หญิง   NaN  NaN                NaN
# 433551  3303168     18/3/2022  หญิง   NaN  NaN                NaN
# 433552  3303169     18/3/2022  หญิง   NaN  NaN                NaN
#
#                                     risk
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                                  ...
# 433548                  ทัณฑสถาน/เรือนจำ
# 433549                  ทัณฑสถาน/เรือนจำ
# 433550                  ทัณฑสถาน/เรือนจำ
# 433551                  ทัณฑสถาน/เรือนจำ
# 433552                  ทัณฑสถาน/เรือนจำ
#
# [3325951 rows x 7 columns]

# %% [markdown]
# ### ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
clean_covid.isnull().any()#ดูค่า Missing รายคอลัมน์ของตาราง data_test2
#เนื่องจากยังมีค่า True แสดงว่าตารางนี้ยังมีค่า Missing
# Out:
# No.                   False
# announce_date         False
# sex                    True
# age                    True
# Unit                   True
# จังหวัดที่ติดเชื้อ     True
# risk                   True
# dtype: bool

# %% [markdown]
# ###แทน missing ด้วยค่าที่เหมาะสม
#
# โดยคำสั่ง fillna() ของตาราง data_covid

# %%
data_covid_updated = clean_covid.fillna(value={'sex':'ไม่รู้', 'age':-99, 'Unit':'ปี', 'risk':'ไม่รู้', 'จังหวัดที่ติดเชื้อ':'ไม่รู้'}) 
#แทน missing ด้วยค่าที่เหมาะสม ในตาราง data_covid_updated 
data_covid_updated
# Out:
#             No. announce_date   sex   age Unit จังหวัดที่ติดเชื้อ  \
# 0             1     12/1/2020  หญิง  61.0   ปี      กรุงเทพมหานคร
# 1             2     17/1/2020  หญิง  74.0   ปี      กรุงเทพมหานคร
# 2             3     22/1/2020  หญิง  73.0   ปี             นครปฐม
# 3             4     22/1/2020   ชาย  68.0   ปี      กรุงเทพมหานคร
# 4             5     24/1/2020  หญิง  66.0   ปี      กรุงเทพมหานคร
# ...         ...           ...   ...   ...  ...                ...
# 433548  3303165     18/3/2022  หญิง   -99   ปี             ไม่รู้
# 433549  3303166     18/3/2022  หญิง   -99   ปี             ไม่รู้
# 433550  3303167     18/3/2022  หญิง   -99   ปี             ไม่รู้
# 433551  3303168     18/3/2022  หญิง   -99   ปี             ไม่รู้
# 433552  3303169     18/3/2022  หญิง   -99   ปี             ไม่รู้
#
#                                     risk
# 0       คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       คนต่างชาติเดินทางมาจากต่างประเทศ
# 2       คนต่างชาติเดินทางมาจากต่างประเทศ
# 3       คนต่างชาติเดินทางมาจากต่างประเทศ
# 4       คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                                  ...
# 433548                  ทัณฑสถาน/เรือนจำ
# 433549                  ทัณฑสถาน/เรือนจำ
# 433550                  ทัณฑสถาน/เรือนจำ
# 433551                  ทัณฑสถาน/เรือนจำ
# 433552                  ทัณฑสถาน/เรือนจำ
#
# [3325951 rows x 7 columns]

# %% [markdown]
# ###ตรวจสอบว่ายังมีค่า Missing หรือไม่

# %%
data_covid_updated.isnull().any() #ดูค่า Missing รายคอลัมน์ของตาราง data_covid_updated หลังแทน missing ด้วยค่าที่เหมาะสม
#เนื่องจากเป็น False ทุกค่า แสดงว่าตารางนี้ไม่มีค่า Missing แล้ว
# Out:
# No.                   False
# announce_date         False
# sex                   False
# age                   False
# Unit                  False
# จังหวัดที่ติดเชื้อ    False
# risk                  False
# dtype: bool

# %% [markdown]
# ##ตารางภูมิภาคของประเทศไทย
#
# ##อ้างอิง
# https://th.wikipedia.org/wiki/%E0%B8%A0%E0%B8%B9%E0%B8%A1%E0%B8%B4%E0%B8%A0%E0%B8%B2%E0%B8%84%E0%B8%82%E0%B8%AD%E0%B8%87%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B9%80%E0%B8%97%E0%B8%A8%E0%B9%84%E0%B8%97%E0%B8%A2?fbclid=IwAR04uAijgnci5l7CmZUvWDlTXgUgzuPYqnkDkeOqPcQ25yBnjmQdf0vDav8

# %%
data_list_region = { 'จังหวัดที่ติดเชื้อ':['อำนาจเจริญ','บึงกาฬ','บุรีรัมย์','ชัยภูมิ','กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม','มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู','หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ','สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร'
              ,'เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์','ตาก','สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์','นครสวรรค์', 'อุทัยธานี','อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร', 'ลพบุรี', 'นครปฐม', 'นนทบุรี'
              ,'ปทุมธานี', 'สมุทรปราการ', 'สมุทรสาคร', 'สมุทรสงคราม', 'สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี','นครนายก','ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด','กาญจนบุรี', 'ราชบุรี','เพชรบุรี', 'ประจวบคีรีขันธ์','ชุมพร', 'นครศรีธรรมราช', 'นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา'
              ,'กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],    #column 1 -> จังหวัด
              '6 ภูมิภาค (ภูมิศาสตร์)':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'
              ,'ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก'
              ,'กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก'
              ,'ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'],   #column 2 -> 6 ภูมิภาค (ภูมิศาสตร์)
              '4 ภูมิภาค (การเมือง)':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'
              ,'ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ'
              ,'เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'
              ,'ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'],   #column 3 -> 4 ภูมิภาค (การเมือง)
              '6 ภูมิภาค (อุตุนิยมวิทยา)':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'
              ,'ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ'
              ,'เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','กลาง','กลาง','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย'
              ,'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน'
              ,'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน'],     #column 4 -> 6 ภูมิภาค (อุตุนิยมวิทยา)	
              '5 ภูมิภาค (การท่องเที่ยว)':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'
              ,'ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ'
              ,'เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','กลาง','กลาง','กลาง','กลาง','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'
              ,'ใต้','ใต้','ใต้','ใต้','ใต้','ใต้']     #column 5 -> 5 ภูมิภาค (การท่องเที่ยว)
}

# %%
data_region = pd.DataFrame.from_dict(data_list_region)   #กำหนดตัวแปร data_region เป็นข้อมูลภูมิภาคของประเทศไทย
data_region   #เรียกดูตารางภูมิภาคของประเทศไทย
# Out:
#    จังหวัดที่ติดเชื้อ 6 ภูมิภาค (ภูมิศาสตร์) 4 ภูมิภาค (การเมือง)  \
# 0          อำนาจเจริญ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 1              บึงกาฬ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 2           บุรีรัมย์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 3             ชัยภูมิ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 4           กาฬสินธุ์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# ..                ...                    ...                  ...
# 72              พังงา                    ใต้                  ใต้
# 73             ภูเก็ต                    ใต้                  ใต้
# 74              ระนอง                    ใต้                  ใต้
# 75               สตูล                    ใต้                  ใต้
# 76               ตรัง                    ใต้                  ใต้
#
#          6 ภูมิภาค (อุตุนิยมวิทยา) 5 ภูมิภาค (การท่องเที่ยว)
# 0               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 1               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 3               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 4               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# ..                             ...                       ...
# 72  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# 73  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# 74  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# 75  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# 76  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
#
# [77 rows x 5 columns]

# %%
covid_region = data_covid_updated.merge(data_region) #เชื่อมตารางข้อมูล data_covid_updata และ data_region โดยใช้คำสั่ง .merge
covid_region
# Out:
#              No. announce_date   sex   age Unit จังหวัดที่ติดเชื้อ  \
# 0              1     12/1/2020  หญิง  61.0   ปี      กรุงเทพมหานคร
# 1              2     17/1/2020  หญิง  74.0   ปี      กรุงเทพมหานคร
# 2              4     22/1/2020   ชาย  68.0   ปี      กรุงเทพมหานคร
# 3              5     24/1/2020  หญิง  66.0   ปี      กรุงเทพมหานคร
# 4              6     25/1/2020  หญิง  33.0   ปี      กรุงเทพมหานคร
# ...          ...           ...   ...   ...  ...                ...
# 2920327  3292162     18/3/2022   ชาย  53.0   ปี             บึงกาฬ
# 2920328  3292163     18/3/2022  หญิง  34.0   ปี             บึงกาฬ
# 2920329  3292164     18/3/2022  หญิง  54.0   ปี             บึงกาฬ
# 2920330  3292165     18/3/2022  หญิง  54.0   ปี             บึงกาฬ
# 2920331  3292166     18/3/2022  หญิง  16.0   ปี             บึงกาฬ
#
#                                      risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 3        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 4        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# ...                                   ...                    ...
# 2920327                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2920328                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2920329                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2920330                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2920331                             อื่นๆ     ตะวันออกเฉียงเหนือ
#
#         4 ภูมิภาค (การเมือง) 6 ภูมิภาค (อุตุนิยมวิทยา)  \
# 0                       กลาง                      กลาง
# 1                       กลาง                      กลาง
# 2                       กลาง                      กลาง
# 3                       กลาง                      กลาง
# 4                       กลาง                      กลาง
# ...                      ...                       ...
# 2920327   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2920328   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2920329   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2920330   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2920331   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
#
#         5 ภูมิภาค (การท่องเที่ยว)
# 0                            กลาง
# 1                            กลาง
# 2                            กลาง
# 3                            กลาง
# 4                            กลาง
# ...                           ...
# 2920327        ตะวันออกเฉียงเหนือ
# 2920328        ตะวันออกเฉียงเหนือ
# 2920329        ตะวันออกเฉียงเหนือ
# 2920330        ตะวันออกเฉียงเหนือ
# 2920331        ตะวันออกเฉียงเหนือ
#
# [2920332 rows x 11 columns]

# %% [markdown]
# ###ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
covid_region.isnull().any() #ดูค่า Missing รายคอลัมน์ของตาราง covid_region หลังแทน missing ด้วยค่าที่เหมาะสม
#เนื่องจากเป็น False ทุกค่า แสดงว่าตารางนี้ไม่มีค่า Missing แล้ว
# Out:
# No.                          False
# announce_date                False
# sex                          False
# age                          False
# Unit                         False
# จังหวัดที่ติดเชื้อ           False
# risk                         False
# 6 ภูมิภาค (ภูมิศาสตร์)       False
# 4 ภูมิภาค (การเมือง)         False
# 6 ภูมิภาค (อุตุนิยมวิทยา)    False
# 5 ภูมิภาค (การท่องเที่ยว)    False
# dtype: bool

# %% [markdown]
# ##ตารางจำนวนประชากรในประเทศไทย แยกตามพื้นที่
#
# https://data.go.th/dataset/statbyyear?fbclid=IwAR367mg3wyYHS6oMUdjOFw-KiZG_3QSIxPtcEtvoFCoy5tDFY0MHDA32fCU

# %%
stat_63 = pd.read_excel(os.path.join(path,'stat_c63.xlsx')) #นำข้อมูลเข้า
stat_63
# Out:
#     ปีเดือน  รหัสจังหวัด    ชื่อจังหวัด  จำนวนประชากรชาย  จำนวนประชากรหญิง  \
# 0      6312            0     ทั่วประเทศ         32375532          33811195
# 1      6312           10  กรุงเทพมหานคร          2625938           2962284
# 2      6312           11    สมุทรปราการ           644516            706963
# 3      6312           12        นนทบุรี           594308            682437
# 4      6312           13       ปทุมธานี           557752            618660
# ..      ...          ...            ...              ...               ...
# 73     6312           92           ตรัง           313368            327206
# 74     6312           93         พัทลุง           254908            268169
# 75     6312           94        ปัตตานี           358611            367404
# 76     6312           95           ยะลา           267919            270683
# 77     6312           96       นราธิวาส           397700            406729
#
#     จำนวนประชากรทั้งหมด  จำนวนบ้าน (หลังคาเรือน)
# 0              66186727                 27224743
# 1               5588222                  3103483
# 2               1351479                   711804
# 3               1276745                   718799
# 4               1176412                   642474
# ..                  ...                      ...
# 73               640574                   234863
# 74               523077                   197086
# 75               726015                   195224
# 76               538602                   170091
# 77               804429                   219403
#
# [78 rows x 7 columns]

# %%
clean_stat = stat_63.rename(columns = {'ชื่อจังหวัด':'จังหวัดที่ติดเชื้อ'}) #ใช้คำสั่ง rename เปลี่ยน ชื่อจังหวัด เป็น จังหวัดที่ติดเชื่อเพื่อให้สามารถเชื่อมกับตาราง covid_region ได้
clean_stat
# Out:
#     ปีเดือน  รหัสจังหวัด จังหวัดที่ติดเชื้อ  จำนวนประชากรชาย  \
# 0      6312            0         ทั่วประเทศ         32375532
# 1      6312           10      กรุงเทพมหานคร          2625938
# 2      6312           11        สมุทรปราการ           644516
# 3      6312           12            นนทบุรี           594308
# 4      6312           13           ปทุมธานี           557752
# ..      ...          ...                ...              ...
# 73     6312           92               ตรัง           313368
# 74     6312           93             พัทลุง           254908
# 75     6312           94            ปัตตานี           358611
# 76     6312           95               ยะลา           267919
# 77     6312           96           นราธิวาส           397700
#
#     จำนวนประชากรหญิง  จำนวนประชากรทั้งหมด  จำนวนบ้าน (หลังคาเรือน)
# 0           33811195             66186727                 27224743
# 1            2962284              5588222                  3103483
# 2             706963              1351479                   711804
# 3             682437              1276745                   718799
# 4             618660              1176412                   642474
# ..               ...                  ...                      ...
# 73            327206               640574                   234863
# 74            268169               523077                   197086
# 75            367404               726015                   195224
# 76            270683               538602                   170091
# 77            406729               804429                   219403
#
# [78 rows x 7 columns]

# %% [markdown]
# ###เลือกข้อมูลที่ต้องการ

# %%
data_stat = clean_stat[['จังหวัดที่ติดเชื้อ','จำนวนประชากรชาย','จำนวนประชากรหญิง','จำนวนประชากรทั้งหมด','จำนวนบ้าน (หลังคาเรือน)']] #เลือก column ที่ต้องการ 
data_stat
# Out:
#    จังหวัดที่ติดเชื้อ  จำนวนประชากรชาย  จำนวนประชากรหญิง  จำนวนประชากรทั้งหมด  \
# 0          ทั่วประเทศ         32375532          33811195             66186727
# 1       กรุงเทพมหานคร          2625938           2962284              5588222
# 2         สมุทรปราการ           644516            706963              1351479
# 3             นนทบุรี           594308            682437              1276745
# 4            ปทุมธานี           557752            618660              1176412
# ..                ...              ...               ...                  ...
# 73               ตรัง           313368            327206               640574
# 74             พัทลุง           254908            268169               523077
# 75            ปัตตานี           358611            367404               726015
# 76               ยะลา           267919            270683               538602
# 77           นราธิวาส           397700            406729               804429
#
#     จำนวนบ้าน (หลังคาเรือน)
# 0                  27224743
# 1                   3103483
# 2                    711804
# 3                    718799
# 4                    642474
# ..                      ...
# 73                   234863
# 74                   197086
# 75                   195224
# 76                   170091
# 77                   219403
#
# [78 rows x 5 columns]

# %% [markdown]
# ###ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
data_stat.isnull().any() #ดูค่า Missing รายคอลัมน์ของตาราง data_stat หลังแทน missing ด้วยค่าที่เหมาะสม
#เนื่องจากเป็น False ทุกค่า แสดงว่าตารางนี้ไม่มีค่า Missing แล้ว
# Out:
# จังหวัดที่ติดเชื้อ         False
# จำนวนประชากรชาย            False
# จำนวนประชากรหญิง           False
# จำนวนประชากรทั้งหมด        False
# จำนวนบ้าน (หลังคาเรือน)    False
# dtype: bool

# %% [markdown]
# #รวมข้อมูลทั้ง 3 ตาราง

# %%
data_total = pd.merge(covid_region,data_stat,on='จังหวัดที่ติดเชื้อ') #ทำการรวมตาราง covid_region และ data_statในแนวนอนโดยใช้คำสั่ง pd.merge
data_total
# Out:
#              No. announce_date   sex   age Unit จังหวัดที่ติดเชื้อ  \
# 0              1     12/1/2020  หญิง  61.0   ปี      กรุงเทพมหานคร
# 1              2     17/1/2020  หญิง  74.0   ปี      กรุงเทพมหานคร
# 2              4     22/1/2020   ชาย  68.0   ปี      กรุงเทพมหานคร
# 3              5     24/1/2020  หญิง  66.0   ปี      กรุงเทพมหานคร
# 4              6     25/1/2020  หญิง  33.0   ปี      กรุงเทพมหานคร
# ...          ...           ...   ...   ...  ...                ...
# 2920327  3292162     18/3/2022   ชาย  53.0   ปี             บึงกาฬ
# 2920328  3292163     18/3/2022  หญิง  34.0   ปี             บึงกาฬ
# 2920329  3292164     18/3/2022  หญิง  54.0   ปี             บึงกาฬ
# 2920330  3292165     18/3/2022  หญิง  54.0   ปี             บึงกาฬ
# 2920331  3292166     18/3/2022  หญิง  16.0   ปี             บึงกาฬ
#
#                                      risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 1        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 2        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 3        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 4        คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# ...                                   ...                    ...
# 2920327                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2920328                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2920329                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2920330                             อื่นๆ     ตะวันออกเฉียงเหนือ
# 2920331                             อื่นๆ     ตะวันออกเฉียงเหนือ
#
#         4 ภูมิภาค (การเมือง) 6 ภูมิภาค (อุตุนิยมวิทยา)  \
# 0                       กลาง                      กลาง
# 1                       กลาง                      กลาง
# 2                       กลาง                      กลาง
# 3                       กลาง                      กลาง
# 4                       กลาง                      กลาง
# ...                      ...                       ...
# 2920327   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2920328   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2920329   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2920330   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2920331   ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
#
#         5 ภูมิภาค (การท่องเที่ยว)  จำนวนประชากรชาย  จำนวนประชากรหญิง  \
# 0                            กลาง          2625938           2962284
# 1                            กลาง          2625938           2962284
# 2                            กลาง          2625938           2962284
# 3                            กลาง          2625938           2962284
# 4                            กลาง          2625938           2962284
# ...                           ...              ...               ...
# 2920327        ตะวันออกเฉียงเหนือ           211673            210369
# 2920328        ตะวันออกเฉียงเหนือ           211673            210369
# 2920329        ตะวันออกเฉียงเหนือ           211673            210369
# 2920330        ตะวันออกเฉียงเหนือ           211673            210369
# 2920331        ตะวันออกเฉียงเหนือ           211673            210369
#
#          จำนวนประชากรทั้งหมด  จำนวนบ้าน (หลังคาเรือน)
# 0                    5588222                  3103483
# 1                    5588222                  3103483
# 2                    5588222                  3103483
# 3                    5588222                  3103483
# 4                    5588222                  3103483
# ...                      ...                      ...
# 2920327               422042                   137871
# 2920328               422042                   137871
# 2920329               422042                   137871
# 2920330               422042                   137871
# 2920331               422042                   137871
#
# [2920332 rows x 15 columns]

# %% [markdown]
# ###ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
data_total.isnull().any() #ดูค่า Missing รายคอลัมน์ของตาราง data_total หลังแทน missing ด้วยค่าที่เหมาะสม
#เนื่องจากเป็น False ทุกค่า แสดงว่าตารางนี้ไม่มีค่า Missing แล้ว
# Out:
# No.                          False
# announce_date                False
# sex                          False
# age                          False
# Unit                         False
# จังหวัดที่ติดเชื้อ           False
# risk                         False
# 6 ภูมิภาค (ภูมิศาสตร์)       False
# 4 ภูมิภาค (การเมือง)         False
# 6 ภูมิภาค (อุตุนิยมวิทยา)    False
# 5 ภูมิภาค (การท่องเที่ยว)    False
# จำนวนประชากรชาย              False
# จำนวนประชากรหญิง             False
# จำนวนประชากรทั้งหมด          False
# จำนวนบ้าน (หลังคาเรือน)      False
# dtype: bool

# %% [markdown]
# #ทำ Dashboard โดยจะใช้ข้อมูลของปี 2020

# %%
Final = data_total[data_total.announce_date.str.contains('2020')] #เลือกเฉพาะข้อมูลในปี 2020 โดยใช้คำสั่ง .announce_date
Final
# Out:
#           No. announce_date   sex   age Unit จังหวัดที่ติดเชื้อ  \
# 0           1     12/1/2020  หญิง  61.0   ปี      กรุงเทพมหานคร
# 1           2     17/1/2020  หญิง  74.0   ปี      กรุงเทพมหานคร
# 2           4     22/1/2020   ชาย  68.0   ปี      กรุงเทพมหานคร
# 3           5     24/1/2020  หญิง  66.0   ปี      กรุงเทพมหานคร
# 4           6     25/1/2020  หญิง  33.0   ปี      กรุงเทพมหานคร
# ...       ...           ...   ...   ...  ...                ...
# 2859403  5922    26/12/2020  หญิง  47.0   ปี             ชัยนาท
# 2864136  5809    24/12/2020  หญิง  44.0   ปี            อ่างทอง
# 2864137  6689    30/12/2020   ชาย  35.0   ปี            อ่างทอง
# 2880862  6288    29/12/2020   ชาย  55.0   ปี               ตราด
# 2893344  6467    30/12/2020   ชาย  57.0   ปี              ระนอง
#
#                                                 risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 1                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 2                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 3                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 4                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# ...                                              ...                    ...
# 2859403                            Cluster สมุทรสาคร                   กลาง
# 2864136                            Cluster สมุทรสาคร                   กลาง
# 2864137  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 2880862                            Cluster สมุทรสาคร               ตะวันออก
# 2893344                            Cluster สมุทรสาคร                    ใต้
#
#         4 ภูมิภาค (การเมือง)       6 ภูมิภาค (อุตุนิยมวิทยา)  \
# 0                       กลาง                            กลาง
# 1                       กลาง                            กลาง
# 2                       กลาง                            กลาง
# 3                       กลาง                            กลาง
# 4                       กลาง                            กลาง
# ...                      ...                             ...
# 2859403                 กลาง                            กลาง
# 2864136                 กลาง                            กลาง
# 2864137                 กลาง                            กลาง
# 2880862                 กลาง                        ตะวันออก
# 2893344                  ใต้  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน
#
#         5 ภูมิภาค (การท่องเที่ยว)  จำนวนประชากรชาย  จำนวนประชากรหญิง  \
# 0                            กลาง          2625938           2962284
# 1                            กลาง          2625938           2962284
# 2                            กลาง          2625938           2962284
# 3                            กลาง          2625938           2962284
# 4                            กลาง          2625938           2962284
# ...                           ...              ...               ...
# 2859403                      กลาง           155013            167464
# 2864136                      กลาง           132393            144191
# 2864137                      กลาง           132393            144191
# 2880862                  ตะวันออก           113131            115405
# 2893344                       ใต้            98154             96218
#
#          จำนวนประชากรทั้งหมด  จำนวนบ้าน (หลังคาเรือน)
# 0                    5588222                  3103483
# 1                    5588222                  3103483
# 2                    5588222                  3103483
# 3                    5588222                  3103483
# 4                    5588222                  3103483
# ...                      ...                      ...
# 2859403               322477                   126673
# 2864136               276584                   101291
# 2864137               276584                   101291
# 2880862               228536                   108270
# 2893344               194372                    92739
#
# [6521 rows x 15 columns]

# %% [markdown]
# ###ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
Final.isnull().any() #ดูค่า Missing รายคอลัมน์ของตาราง Final หลังแทน missing ด้วยค่าที่เหมาะสม
#เนื่องจากเป็น False ทุกค่า แสดงว่าตารางนี้ไม่มีค่า Missing แล้ว
# Out:
# No.                          False
# announce_date                False
# sex                          False
# age                          False
# Unit                         False
# จังหวัดที่ติดเชื้อ           False
# risk                         False
# 6 ภูมิภาค (ภูมิศาสตร์)       False
# 4 ภูมิภาค (การเมือง)         False
# 6 ภูมิภาค (อุตุนิยมวิทยา)    False
# 5 ภูมิภาค (การท่องเที่ยว)    False
# จำนวนประชากรชาย              False
# จำนวนประชากรหญิง             False
# จำนวนประชากรทั้งหมด          False
# จำนวนบ้าน (หลังคาเรือน)      False
# dtype: bool

# %% [markdown]
# ##ข้อมูลที่ใช้โหลดใน Dashboard

# %%
Town_merge =Final[['จังหวัดที่ติดเชื้อ','จำนวนประชากรทั้งหมด']] #เลือก column ที่ต้องการจาก Final
Town_merge
# Out:
#         จังหวัดที่ติดเชื้อ  จำนวนประชากรทั้งหมด
# 0            กรุงเทพมหานคร              5588222
# 1            กรุงเทพมหานคร              5588222
# 2            กรุงเทพมหานคร              5588222
# 3            กรุงเทพมหานคร              5588222
# 4            กรุงเทพมหานคร              5588222
# ...                    ...                  ...
# 2859403             ชัยนาท               322477
# 2864136            อ่างทอง               276584
# 2864137            อ่างทอง               276584
# 2880862               ตราด               228536
# 2893344              ระนอง               194372
#
# [6521 rows x 2 columns]

# %%
Town =Final.groupby(['จังหวัดที่ติดเชื้อ']).count().reset_index()  #ใช้ group ในการนับ จังหวัดที่ซํ้าให้กลายเป็นจำนวนเดียว
Town
# Out:
#    จังหวัดที่ติดเชื้อ   No.  announce_date   sex   age  Unit  risk  \
# 0              กระบี่    27             27    27    27    27    27
# 1       กรุงเทพมหานคร  2214           2214  2214  2214  2214  2214
# 2           กาญจนบุรี    10             10    10    10    10    10
# 3           กาฬสินธุ์     3              3     3     3     3     3
# 4           กำแพงเพชร     1              1     1     1     1     1
# ..                ...   ...            ...   ...   ...   ...   ...
# 70           เพชรบุรี    22             22    22    22    22    22
# 71          เพชรบูรณ์     4              4     4     4     4     4
# 72                เลย     7              7     7     7     7     7
# 73               แพร่     1              1     1     1     1     1
# 74         แม่ฮ่องสอน     5              5     5     5     5     5
#
#     6 ภูมิภาค (ภูมิศาสตร์)  4 ภูมิภาค (การเมือง)  6 ภูมิภาค (อุตุนิยมวิทยา)  \
# 0                       27                    27                         27
# 1                     2214                  2214                       2214
# 2                       10                    10                         10
# 3                        3                     3                          3
# 4                        1                     1                          1
# ..                     ...                   ...                        ...
# 70                      22                    22                         22
# 71                       4                     4                          4
# 72                       7                     7                          7
# 73                       1                     1                          1
# 74                       5                     5                          5
#
#     5 ภูมิภาค (การท่องเที่ยว)  จำนวนประชากรชาย  จำนวนประชากรหญิง  \
# 0                          27               27                27
# 1                        2214             2214              2214
# 2                          10               10                10
# 3                           3                3                 3
# 4                           1                1                 1
# ..                        ...              ...               ...
# 70                         22               22                22
# 71                          4                4                 4
# 72                          7                7                 7
# 73                          1                1                 1
# 74                          5                5                 5
#
#     จำนวนประชากรทั้งหมด  จำนวนบ้าน (หลังคาเรือน)
# 0                    27                       27
# 1                  2214                     2214
# 2                    10                       10
# 3                     3                        3
# 4                     1                        1
# ..                  ...                      ...
# 70                   22                       22
# 71                    4                        4
# 72                    7                        7
# 73                    1                        1
# 74                    5                        5
#
# [75 rows x 15 columns]

# %%
data_Town = pd.merge(Town_merge,Town,on='จังหวัดที่ติดเชื้อ').iloc[:,:3]  #รวมตารางในแนวนอนจากนั้นตัดเอาเฉพาะ column ที่ต้องการ
data_Town =data_Town.rename(columns = {'จำนวนประชากรทั้งหมด_x':'จำนวนประชากรทั้งหมด','No.':'จำนวนผู้ติดเชื้อ'}) #เปลี่ยนชื่อ column
data_Town
# Out:
#      จังหวัดที่ติดเชื้อ  จำนวนประชากรทั้งหมด  จำนวนผู้ติดเชื้อ
# 0         กรุงเทพมหานคร              5588222              2214
# 1         กรุงเทพมหานคร              5588222              2214
# 2         กรุงเทพมหานคร              5588222              2214
# 3         กรุงเทพมหานคร              5588222              2214
# 4         กรุงเทพมหานคร              5588222              2214
# ...                 ...                  ...               ...
# 6516             ชัยนาท               322477                 6
# 6517            อ่างทอง               276584                 2
# 6518            อ่างทอง               276584                 2
# 6519               ตราด               228536                 1
# 6520              ระนอง               194372                 1
#
# [6521 rows x 3 columns]

# %%
final_town = pd.merge(Final,data_Town,on='จังหวัดที่ติดเชื้อ') #เชื่อมตาราง จังหวัดที่ติดเชื้อ
final_town
# Out:
#           No. announce_date   sex   age Unit จังหวัดที่ติดเชื้อ  \
# 0           1     12/1/2020  หญิง  61.0   ปี      กรุงเทพมหานคร
# 1           1     12/1/2020  หญิง  61.0   ปี      กรุงเทพมหานคร
# 2           1     12/1/2020  หญิง  61.0   ปี      กรุงเทพมหานคร
# 3           1     12/1/2020  หญิง  61.0   ปี      กรุงเทพมหานคร
# 4           1     12/1/2020  หญิง  61.0   ปี      กรุงเทพมหานคร
# ...       ...           ...   ...   ...  ...                ...
# 7791182  5809    24/12/2020  หญิง  44.0   ปี            อ่างทอง
# 7791183  6689    30/12/2020   ชาย  35.0   ปี            อ่างทอง
# 7791184  6689    30/12/2020   ชาย  35.0   ปี            อ่างทอง
# 7791185  6288    29/12/2020   ชาย  55.0   ปี               ตราด
# 7791186  6467    30/12/2020   ชาย  57.0   ปี              ระนอง
#
#                                                 risk 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 1                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 2                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 3                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# 4                   คนต่างชาติเดินทางมาจากต่างประเทศ                   กลาง
# ...                                              ...                    ...
# 7791182                            Cluster สมุทรสาคร                   กลาง
# 7791183  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 7791184  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                   กลาง
# 7791185                            Cluster สมุทรสาคร               ตะวันออก
# 7791186                            Cluster สมุทรสาคร                    ใต้
#
#         4 ภูมิภาค (การเมือง)       6 ภูมิภาค (อุตุนิยมวิทยา)  \
# 0                       กลาง                            กลาง
# 1                       กลาง                            กลาง
# 2                       กลาง                            กลาง
# 3                       กลาง                            กลาง
# 4                       กลาง                            กลาง
# ...                      ...                             ...
# 7791182                 กลาง                            กลาง
# 7791183                 กลาง                            กลาง
# 7791184                 กลาง                            กลาง
# 7791185                 กลาง                        ตะวันออก
# 7791186                  ใต้  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน
#
#         5 ภูมิภาค (การท่องเที่ยว)  จำนวนประชากรชาย  จำนวนประชากรหญิง  \
# 0                            กลาง          2625938           2962284
# 1                            กลาง          2625938           2962284
# 2                            กลาง          2625938           2962284
# 3                            กลาง          2625938           2962284
# 4                            กลาง          2625938           2962284
# ...                           ...              ...               ...
# 7791182                      กลาง           132393            144191
# 7791183                      กลาง           132393            144191
# 7791184                      กลาง           132393            144191
# 7791185                  ตะวันออก           113131            115405
# 7791186                       ใต้            98154             96218
#
#          จำนวนประชากรทั้งหมด_x  จำนวนบ้าน (หลังคาเรือน)  \
# 0                      5588222                  3103483
# 1                      5588222                  3103483
# 2                      5588222                  3103483
# 3                      5588222                  3103483
# 4                      5588222                  3103483
# ...                        ...                      ...
# 7791182                 276584                   101291
# 7791183                 276584                   101291
# 7791184                 276584                   101291
# 7791185                 228536                   108270
# 7791186                 194372                    92739
#
#          จำนวนประชากรทั้งหมด_y  จำนวนผู้ติดเชื้อ
# 0                      5588222              2214
# 1                      5588222              2214
# 2                      5588222              2214
# 3                      5588222              2214
# 4                      5588222              2214
# ...                        ...               ...
# 7791182                 276584                 2
# 7791183                 276584                 2
# 7791184                 276584                 2
# 7791185                 228536                 1
# 7791186                 194372                 1
#
# [7791187 rows x 17 columns]

# %%
final_group = final_town.groupby(['จังหวัดที่ติดเชื้อ']).first() #ใช้ groupby ในการนับจำนวนซํ้าจากนั้นแสดงตารางออกมา .first คือการนับแค่ตัวแรกที่ซํ้าออกมา
final_group
# Out:
#                      No. announce_date   sex   age Unit  \
# จังหวัดที่ติดเชื้อ
# กระบี่                24      4/2/2020  หญิง  31.0   ปี
# กรุงเทพมหานคร          1     12/1/2020  หญิง  61.0   ปี
# กาญจนบุรี            330     21/3/2020   ชาย  68.0   ปี
# กาฬสินธุ์            188     18/3/2020   ชาย  55.0   ปี
# กำแพงเพชร           5758    23/12/2020   ชาย  43.0   ปี
# ...                  ...           ...   ...   ...  ...
# เพชรบุรี             838     25/3/2020   ชาย  23.0   ปี
# เพชรบูรณ์            147     16/3/2020   ชาย  67.0   ปี
# เลย                  423     22/3/2020   ชาย  22.0   ปี
# แพร่                 431     22/3/2020   ชาย  35.0   ปี
# แม่ฮ่องสอน          1090     27/3/2020   ชาย  32.0   ปี
#
#                                                            risk  \
# จังหวัดที่ติดเชื้อ
# กระบี่                         คนต่างชาติเดินทางมาจากต่างประเทศ
# กรุงเทพมหานคร                  คนต่างชาติเดินทางมาจากต่างประเทศ
# กาญจนบุรี                                               สนามมวย
# กาฬสินธุ์                                               สนามมวย
# กำแพงเพชร                                     Cluster สมุทรสาคร
# ...                                                         ...
# เพชรบุรี            สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# เพชรบูรณ์                      คนต่างชาติเดินทางมาจากต่างประเทศ
# เลย                                                     สนามมวย
# แพร่                                                    สนามมวย
# แม่ฮ่องสอน                        คนไทยเดินทางกลับจากต่างประเทศ
#
#                    6 ภูมิภาค (ภูมิศาสตร์) 4 ภูมิภาค (การเมือง)  \
# จังหวัดที่ติดเชื้อ
# กระบี่                                ใต้                  ใต้
# กรุงเทพมหานคร                        กลาง                 กลาง
# กาญจนบุรี                         ตะวันตก                 กลาง
# กาฬสินธุ์              ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# กำแพงเพชร                            กลาง                เหนือ
# ...                                   ...                  ...
# เพชรบุรี                          ตะวันตก                 กลาง
# เพชรบูรณ์                            กลาง                เหนือ
# เลย                    ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# แพร่                                เหนือ                เหนือ
# แม่ฮ่องสอน                          เหนือ                เหนือ
#
#                          6 ภูมิภาค (อุตุนิยมวิทยา) 5 ภูมิภาค (การท่องเที่ยว)  \
# จังหวัดที่ติดเชื้อ
# กระบี่              ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                       ใต้
# กรุงเทพมหานคร                                 กลาง                      กลาง
# กาญจนบุรี                                     กลาง                      กลาง
# กาฬสินธุ์                       ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# กำแพงเพชร                                    เหนือ                     เหนือ
# ...                                            ...                       ...
# เพชรบุรี            ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย                      กลาง
# เพชรบูรณ์                                    เหนือ                     เหนือ
# เลย                             ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# แพร่                                         เหนือ                     เหนือ
# แม่ฮ่องสอน                                   เหนือ                     เหนือ
#
#                     จำนวนประชากรชาย  จำนวนประชากรหญิง  จำนวนประชากรทั้งหมด_x  \
# จังหวัดที่ติดเชื้อ
# กระบี่                       237242            240528                 477770
# กรุงเทพมหานคร               2625938           2962284                5588222
# กาญจนบุรี                    447983            443993                 891976
# กาฬสินธุ์                    483447            493728                 977175
# กำแพงเพชร                    352711            361407                 714118
# ...                             ...               ...                    ...
# เพชรบุรี                     232915            249278                 482193
# เพชรบูรณ์                    484886            497054                 981940
# เลย                          320165            318571                 638736
# แพร่                         210973            226377                 437350
# แม่ฮ่องสอน                   144311            140238                 284549
#
#                     จำนวนบ้าน (หลังคาเรือน)  จำนวนประชากรทั้งหมด_y  \
# จังหวัดที่ติดเชื้อ
# กระบี่                               193701                 477770
# กรุงเทพมหานคร                       3103483                5588222
# กาญจนบุรี                            348371                 891976
# กาฬสินธุ์                            311145                 977175
# กำแพงเพชร                            278306                 714118
# ...                                     ...                    ...
# เพชรบุรี                             220362                 482193
# เพชรบูรณ์                            364119                 981940
# เลย                                  226892                 638736
# แพร่                                 179040                 437350
# แม่ฮ่องสอน                           115163                 284549
#
#                     จำนวนผู้ติดเชื้อ
# จังหวัดที่ติดเชื้อ
# กระบี่                            27
# กรุงเทพมหานคร                   2214
# กาญจนบุรี                         10
# กาฬสินธุ์                          3
# กำแพงเพชร                          1
# ...                              ...
# เพชรบุรี                          22
# เพชรบูรณ์                          4
# เลย                                7
# แพร่                               1
# แม่ฮ่องสอน                         5
#
# [75 rows x 16 columns]

# %%
final_group2 =final_group[['จำนวนประชากรทั้งหมด_x','6 ภูมิภาค (ภูมิศาสตร์)','4 ภูมิภาค (การเมือง)','6 ภูมิภาค (อุตุนิยมวิทยา)','5 ภูมิภาค (การท่องเที่ยว)','จำนวนประชากรชาย','จำนวนประชากรหญิง','จำนวนผู้ติดเชื้อ','จำนวนบ้าน (หลังคาเรือน)','announce_date']]
#เลือกคอลัมน์ที่ต้องการ
final_group2 =final_group2.rename(columns = {'จำนวนประชากรทั้งหมด_x':'จำนวนประชากรทั้งหมด'}) 
final_group3 = final_group2
final_group3
# Out:
#                     จำนวนประชากรทั้งหมด 6 ภูมิภาค (ภูมิศาสตร์)  \
# จังหวัดที่ติดเชื้อ
# กระบี่                           477770                    ใต้
# กรุงเทพมหานคร                   5588222                   กลาง
# กาญจนบุรี                        891976                ตะวันตก
# กาฬสินธุ์                        977175     ตะวันออกเฉียงเหนือ
# กำแพงเพชร                        714118                   กลาง
# ...                                 ...                    ...
# เพชรบุรี                         482193                ตะวันตก
# เพชรบูรณ์                        981940                   กลาง
# เลย                              638736     ตะวันออกเฉียงเหนือ
# แพร่                             437350                  เหนือ
# แม่ฮ่องสอน                       284549                  เหนือ
#
#                    4 ภูมิภาค (การเมือง)       6 ภูมิภาค (อุตุนิยมวิทยา)  \
# จังหวัดที่ติดเชื้อ
# กระบี่                              ใต้  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน
# กรุงเทพมหานคร                      กลาง                            กลาง
# กาญจนบุรี                          กลาง                            กลาง
# กาฬสินธุ์            ตะวันออกเฉียงเหนือ              ตะวันออกเฉียงเหนือ
# กำแพงเพชร                         เหนือ                           เหนือ
# ...                                 ...                             ...
# เพชรบุรี                           กลาง  ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย
# เพชรบูรณ์                         เหนือ                           เหนือ
# เลย                  ตะวันออกเฉียงเหนือ              ตะวันออกเฉียงเหนือ
# แพร่                              เหนือ                           เหนือ
# แม่ฮ่องสอน                        เหนือ                           เหนือ
#
#                    5 ภูมิภาค (การท่องเที่ยว)  จำนวนประชากรชาย  \
# จังหวัดที่ติดเชื้อ
# กระบี่                                   ใต้           237242
# กรุงเทพมหานคร                           กลาง          2625938
# กาญจนบุรี                               กลาง           447983
# กาฬสินธุ์                 ตะวันออกเฉียงเหนือ           483447
# กำแพงเพชร                              เหนือ           352711
# ...                                      ...              ...
# เพชรบุรี                                กลาง           232915
# เพชรบูรณ์                              เหนือ           484886
# เลย                       ตะวันออกเฉียงเหนือ           320165
# แพร่                                   เหนือ           210973
# แม่ฮ่องสอน                             เหนือ           144311
#
#                     จำนวนประชากรหญิง  จำนวนผู้ติดเชื้อ  \
# จังหวัดที่ติดเชื้อ
# กระบี่                        240528                27
# กรุงเทพมหานคร                2962284              2214
# กาญจนบุรี                     443993                10
# กาฬสินธุ์                     493728                 3
# กำแพงเพชร                     361407                 1
# ...                              ...               ...
# เพชรบุรี                      249278                22
# เพชรบูรณ์                     497054                 4
# เลย                           318571                 7
# แพร่                          226377                 1
# แม่ฮ่องสอน                    140238                 5
#
#                     จำนวนบ้าน (หลังคาเรือน) announce_date
# จังหวัดที่ติดเชื้อ
# กระบี่                               193701      4/2/2020
# กรุงเทพมหานคร                       3103483     12/1/2020
# กาญจนบุรี                            348371     21/3/2020
# กาฬสินธุ์                            311145     18/3/2020
# กำแพงเพชร                            278306    23/12/2020
# ...                                     ...           ...
# เพชรบุรี                             220362     25/3/2020
# เพชรบูรณ์                            364119     16/3/2020
# เลย                                  226892     22/3/2020
# แพร่                                 179040     22/3/2020
# แม่ฮ่องสอน                           115163     27/3/2020
#
# [75 rows x 10 columns]

# %% [markdown]
# ### เก็บข้อมูลเพศ

# %%
Final_male = Final[Final['sex']=='ชาย'] #นับจำนวนเพศชาย

# %%
count_male =Final_male.groupby(['sex']).count().reset_index()  # groupby เพศชาย
count_male
# Out:
#    sex   No.  announce_date   age  Unit  จังหวัดที่ติดเชื้อ  risk  \
# 0  ชาย  2753           2753  2753  2753                2753  2753
#
#    6 ภูมิภาค (ภูมิศาสตร์)  4 ภูมิภาค (การเมือง)  6 ภูมิภาค (อุตุนิยมวิทยา)  \
# 0                    2753                  2753                       2753
#
#    5 ภูมิภาค (การท่องเที่ยว)  จำนวนประชากรชาย  จำนวนประชากรหญิง  \
# 0                       2753             2753              2753
#
#    จำนวนประชากรทั้งหมด  จำนวนบ้าน (หลังคาเรือน)
# 0                 2753                     2753

# %%
Final_female = Final[Final['sex']=='หญิง']#นับจำนวนเพศหญิง

# %%
count_female = Final_female.groupby(['sex']).count().reset_index()  # groupby เพศหญิง
count_female
# Out:
#     sex   No.  announce_date   age  Unit  จังหวัดที่ติดเชื้อ  risk  \
# 0  หญิง  2416           2416  2416  2416                2416  2416
#
#    6 ภูมิภาค (ภูมิศาสตร์)  4 ภูมิภาค (การเมือง)  6 ภูมิภาค (อุตุนิยมวิทยา)  \
# 0                    2416                  2416                       2416
#
#    5 ภูมิภาค (การท่องเที่ยว)  จำนวนประชากรชาย  จำนวนประชากรหญิง  \
# 0                       2416             2416              2416
#
#    จำนวนประชากรทั้งหมด  จำนวนบ้าน (หลังคาเรือน)
# 0                 2416                     2416

# %%
UnKnow = Final[Final['sex']=='ไม่รู้']#นับจำนวนเพศที่ไม่รู้

# %%
count_UnKnow =UnKnow.groupby(['sex']).count().reset_index()  # groupby ไม่รู้เพศ
count_UnKnow
# Out:
#       sex   No.  announce_date   age  Unit  จังหวัดที่ติดเชื้อ  risk  \
# 0  ไม่รู้  1352           1352  1352  1352                1352  1352
#
#    6 ภูมิภาค (ภูมิศาสตร์)  4 ภูมิภาค (การเมือง)  6 ภูมิภาค (อุตุนิยมวิทยา)  \
# 0                    1352                  1352                       1352
#
#    5 ภูมิภาค (การท่องเที่ยว)  จำนวนประชากรชาย  จำนวนประชากรหญิง  \
# 0                       1352             1352              1352
#
#    จำนวนประชากรทั้งหมด  จำนวนบ้าน (หลังคาเรือน)
# 0                 1352                     1352

# %%
Final1 =Final.groupby(['sex']).count().reset_index()  ## หาจำนวนผู้ติดเชื้อโควิค-19 แบ่งตาม sex
Final1
# Out:
#       sex   No.  announce_date   age  Unit  จังหวัดที่ติดเชื้อ  risk  \
# 0     ชาย  2753           2753  2753  2753                2753  2753
# 1    หญิง  2416           2416  2416  2416                2416  2416
# 2  ไม่รู้  1352           1352  1352  1352                1352  1352
#
#    6 ภูมิภาค (ภูมิศาสตร์)  4 ภูมิภาค (การเมือง)  6 ภูมิภาค (อุตุนิยมวิทยา)  \
# 0                    2753                  2753                       2753
# 1                    2416                  2416                       2416
# 2                    1352                  1352                       1352
#
#    5 ภูมิภาค (การท่องเที่ยว)  จำนวนประชากรชาย  จำนวนประชากรหญิง  \
# 0                       2753             2753              2753
# 1                       2416             2416              2416
# 2                       1352             1352              1352
#
#    จำนวนประชากรทั้งหมด  จำนวนบ้าน (หลังคาเรือน)
# 0                 2753                     2753
# 1                 2416                     2416
# 2                 1352                     1352

# %% [markdown]
# ### Download ไฟล์

# %%
Final.to_csv('Final.csv', encoding='utf-8')

# %%
Final1.to_csv('Final1.csv', encoding='utf-8')

# %%
count_male.to_csv('count_male.csv', encoding='utf-8')

# %%
count_female.to_csv('count_female.csv', encoding='utf-8')

# %%
count_UnKnow.to_csv('count_UnKnow.csv', encoding='utf-8')

# %%
Town.to_csv('Town.csv', encoding='utf-8')

# %%
data_Town.to_csv('data_Town.csv', encoding='utf-8')

# %%
final_group3.to_csv('finai_group3.csv', encoding='utf-8')

# %% [markdown]
# # ลิ้ง Dashboard
# https://datastudio.google.com/u/0/reporting/eac0f385-c9f6-4495-bd07-bc125a82b4ab/page/c1roC?fbclid=IwAR0jHU4H28UvCbnkje5RtpmmEI4dW15ecTzf2xAOMUtKqIgKlPsmGwkNsxE
